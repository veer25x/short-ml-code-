# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/veerp/OneDrive/Desktop/ml/homeprices.csv")
print(df.head())
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
y = df[['price']] 
x = df[['area']]

# %%
x
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
y
# Out:
#     price
# 0  550000
# 1  565000
# 2  610000
# 3  680000
# 4  725000

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
print(df['area'].dtype)
# Out:
# int64

# %%
print(df['price'].dtype)
# Out:
# int64

# %%
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
predictions = model.predict([[3300]])
print("Predictions:", predictions[0])
# Out:
# Predictions: [628715.75342466]
# C:\Users\veerp\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df = pd.read_csv("C:/Users/veerp/OneDrive/Desktop/ml/areas.csv")

# %%
df
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
print(z)
print(type(z))
# Out:
# [['area']]
# <class 'list'>

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   area    13 non-null     int64
# dtypes: int64(1)
# memory usage: 236.0 bytes

# %%
z=[["area"]]

# %%
predictions = model.predict(z)
# Out:
# C:\Users\veerp\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 predictions = model.predict(z)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:285, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
#     283     check_is_fitted(self)
# --> 285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#     287     if coef_.ndim == 1:
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1053, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1050         raise ValueError(msg)
#    1052 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
# -> 1053     raise ValueError(
#    1054         "dtype='numeric' is not compatible with arrays of bytes/strings."
#    1055         "Convert your data to numeric values explicitly instead."
#    1056     )
#    1057 if not allow_nd and array.ndim >= 3:
#    1058     raise ValueError(
#    1059         "Found array with dim %d. %s expected <= 2."
#    1060         % (array.ndim, estimator_name)
#    1061     )
#
# ValueError: dtype='numeric' is not compatible with arrays of bytes/strings.Convert your data to numeric values explicitly instead.

# %%
predictions[:13]
# Out:
# array([[628715.75342466]])
